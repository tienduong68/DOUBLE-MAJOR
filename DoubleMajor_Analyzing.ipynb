# %%
import pandas as pd
import numpy as np

# %%
path1 = 'DOUBLE MAJOR/DoubleMajor_MARKETING_Cleaned.xlsx'
path2 = 'DOUBLE MAJOR/DoubleMajor_MIS_Cleaned.xlsx'
df1 = pd.read_excel(path1)
df2 = pd.read_excel(path2)

# %%
common_rows = pd.merge(df1,df2, on=['Course_ID', 'Course_Name'], how='inner')

# %%
common_courses
# Out:
#                               Index Course_ID Course_Name  Credits Department
# 0   2. Kiến thức giáo dục đại cương       NaN         NaN      NaN        NaN
# 1                          Bắt Buộc       NaN         NaN      NaN        NaN
# 2                          Bắt Buộc       NaN         NaN      NaN        NaN
# 3                          Bắt Buộc       NaN         NaN      NaN        NaN
# 4                          Bắt Buộc       NaN         NaN      NaN        NaN
# ..                              ...       ...         ...      ...        ...
# 67                5. Học phần chung       NaN         NaN      NaN        NaN
# 68           6. Học phần của trường       NaN         NaN      NaN        NaN
# 69            7. Học phần của ngành       NaN         NaN      NaN        NaN
# 70                   8. Cơ sở ngành       NaN         NaN      NaN        NaN
# 71               9. Kiến thức ngành       NaN         NaN      NaN        NaN
#
# [72 rows x 5 columns]

# %%
df = common_courses.dropna()

# %%
df
# Out:
#    Index Course_ID                             Course_Name  Credits  \
# 50    29  LLDL1102          Lịch sử Đảng Cộng sản Việt Nam      2.0
# 51    30  LLNL1105                   Triết học Mác - Lênin      3.0
# 52    31  LLNL1106           Kinh tế chính trị Mác - Lênin      2.0
# 53    32  LLNL1107               Chủ nghĩa xã hội khoa học      2.0
# 54    33  LLTT1101                    Tư tưởng Hồ Chí Minh      2.0
# 65    43  TIKT1139  Trực quan hóa dữ liệu trong kinh doanh      3.0
#
#                                 Department
# 50                  Khoa Lý luận chính trị
# 51                  Khoa Lý luận chính trị
# 52                  Khoa Lý luận chính trị
# 53                  Khoa Lý luận chính trị
# 54                  Khoa Lý luận chính trị
# 65  Viện Công nghệ thông tin và Kinh tế số
